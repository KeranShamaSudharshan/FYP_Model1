# %% [markdown]
# # 01 - Data Preprocessing (Detailed Explanation)
#
# ## Overview
# **Purpose**: Prepare training data for machine learning models that will cluster students in real-time.
#
# **What we'll do**:
# 1. Load quiz response data and participant tracking data
# 2. Filter ONLY students who participated (joined sessions)
# 3. Apply dynamic cluster assignment logic to create training labels
# 4. Create separate features for different question types
# 5. Scale features for model training
# 6. Save preprocessed data
#
# **Output**: 10 files ready for model training

# %% [markdown]
# ## Step 1: Mount Google Drive
#
# **What this does**: Connects this Colab notebook to your Google Drive so we can read/write files.
#
# **Why needed**: Our datasets (Merge_Enhanced_Fixed.csv, Participant_Tracking.csv) are stored in Drive.

# %%
# Line 1: Import drive module from google.colab package
#   - drive: Module that handles Google Drive operations
#   - google.colab: Package available only in Colab environment
from google.colab import drive

# Line 2: Mount (connect) Google Drive to this Colab notebook
#   - '/content/drive': Location where Drive files will appear
#   - After running, you'll see "Drive" folder in left sidebar
#   - You may need to authorize access (click link, sign in)
drive.mount('/content/drive')
